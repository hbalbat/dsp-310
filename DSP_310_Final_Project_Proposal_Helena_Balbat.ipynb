# %% [markdown]
# <a href="https://colab.research.google.com/github/hbalbat/dsp-310/blob/main/DSP_310_Final_Project_Proposal_Helena_Balbat.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DSP 310: Final Project Proposal
#
# ## Helena Balbat
#
# ### Project Selected - Individual Project: Data Analysis and Modeling

# %% [markdown]
# ###Dataset: Drug Classification (found on Kaggle)

# %%
# importing beginning packages
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/hbalbat/dsp-310/main/drug200.csv'

df = pd.read_csv(url)
df.head()
# Out:
#    Age Sex      BP Cholesterol  Na_to_K   Drug
# 0   23   F    HIGH        HIGH   25.355  DrugY
# 1   47   M     LOW        HIGH   13.093  drugC
# 2   47   M     LOW        HIGH   10.114  drugC
# 3   28   F  NORMAL        HIGH    7.798  drugX
# 4   61   F     LOW        HIGH   18.043  DrugY

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Age          200 non-null    int64
#  1   Sex          200 non-null    object
#  2   BP           200 non-null    object
#  3   Cholesterol  200 non-null    object
#  4   Na_to_K      200 non-null    float64
#  5   Drug         200 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 9.5+ KB

# %%
df.describe()
# Out:
#               Age     Na_to_K
# count  200.000000  200.000000
# mean    44.315000   16.084485
# std     16.544315    7.223956
# min     15.000000    6.269000
# 25%     31.000000   10.445500
# 50%     45.000000   13.936500
# 75%     58.000000   19.380000
# max     74.000000   38.247000

# %% [markdown]
# ### Describing the dataset:
#
# This dataset contains 6 columns and 200 entries (rows). Only two columns are numerical, these being age and Na_to_K (sodium to potassium ratio). The other four columns - sex, BP (blood pressure), cholesterol, and drug - are categorical. The target feature of this dataset is the drug type. We can use the other features to classify which drug should be prescribed.

# %%
import seaborn as sns
sns.set()

# %%
sns.pairplot(df, hue='Drug', height=3, vars=["Age", "Na_to_K"])

# %%
df['Drug'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='Drug'>

# %%
df["Age"].plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %%
plot_series = df['BP']
plot_series.name = '' # get rid of the 'BP' label

# %%
plot_series.value_counts().plot.pie() # plot the value counts of the labels for blood pressure
# Out:
# <Axes: ylabel='count'>

# %%
df["Na_to_K"].plot.hist(bins=10)
# Out:
# <Axes: ylabel='Frequency'>

# %%
import seaborn as sns
sns.set()
sns.pairplot(df, hue='Drug', height=3, vars=["Age","Sex","BP","Cholesterol","Na_to_K"])

# %% [markdown]
# ## Outline of Proposed Analysis:
#
# ### What	question(s)	are	you	trying	to	answer	with	your	analysis?
# I am trying to determine the factors that may determine/classify which drug should be prescribed to a patient. Any of the other features, such as age, cholesterol, blood pressure, or Na_to_K ratios, could determine best which drug should be prescribed. I would like to see how accurately a drug can be prescribed to a patient based on their individual data, based on the algorithm's training.
#
# ### What	kind	of	ML	models	of	the	data	are	you	building?		Your	final	project	has	to	include	at	least	one	kind	of	ML	model,	e.g.	classification,	regression,	or	clustering	model	and	you	have	to	tune	the	model	and	report	the	best	possible	model.		For	classification	and	regression	model	you	will	need	to	also	report	the	95%	confidence	interval.
# I plan to build classification models for this dataset. Ideally, decision trees and/or KNN/MLP models. These will most likely be able to determine the accuracy of the classifications for drug prescription. I will also be able to evaluate the best model that avoids over- or underfitting the dataset. I will also be reporting the 95% confidence intervals for these models, discussing the statistical significance and determining if there are differences between models in terms of accuracy.
#
# ### What	kind	of	results	do	you	expect	from	the	analysis?
# From the analysis of this dataset, I expect to determine the factors that determine which drug should be prescribed to a patient. I would like to see if there are any drugs that are prescribed to a particular group, creating a distinct cluster of data. I expect there to be certain models that will most accurately test the data, and most likely, they will be closest to the medium complexity models. I can use grid search cross-validation to evaluate the performance of these models.
